# %%
import re

input_file = "maithili_corpus.txt"
output_file = "maithili_cleaned.txt"
max_sentences = 30000

all_sentences = []

with open(input_file, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue

        #Split line into sentences by Devanagari danda
        for sentence in re.split(r'[।॥]', line):
            s = sentence.strip()          #remove spaces
            s = s.rstrip('|')             #remove trailing |
            #Remove English letters, English digits, and Devanagari digits
            s = re.sub(r'[A-Za-z0-9\u0966-\u096F]', '', s)
            
            if s:
                all_sentences.append(s) 
                if len(all_sentences) >= max_sentences:
                    break
        if len(all_sentences) >= max_sentences:
            break

with open(output_file, 'w', encoding='utf-8') as f:
    for s in all_sentences:
        f.write(s + "\n")
print(f"Done! Total sentences: {len(all_sentences)}")
print(f"Saved to: {output_file}")
# Out:
# Done! Total sentences: 30000
# Saved to: maithili_cleaned.txt

# %%
file_path = "maithili_corpus.txt"

with open(file_path, "r", encoding="utf-8") as f:
    text = f.read()

print(text[:500])
# Out:
# अङ्ग्रेजी एक पश्चिमजर्मनीक भाषा छी। प्रारम्भमे ई भाषा मात्र इङ्ल्यान्डमे बाजल जाएत छल मुदा एखन ई भाषा विश्वव्यापी रूपमे बाजल जाएत अछि। बेलायत संयुक्त राज्य अमेरिका क्यानाडा दक्षिण अफ्रिका अस्ट्रेलिया आ न्युजिल्यान्डमे मुख्य बोलीके रूपमे ई भाषाक प्रयोग कएल जाएत अछि। ई विश्वक बहुत रास स्थानमे बाजल जाएवाला भाषा छी। अङ्ग्रेजी भाषा कऽ विश्वक बहुत देशसभमे अन्तर्राष्ट्रिय भाषाक रुपमे सेहो बाजल जाएत अछि।
#
# अछाम नेपालक सुदूरपश्चिमाञ्चल विकास क्षेत्रमे रहल एक पहाडी जिला छी। १६८० वर्ग किलोमिटरमे फैलल अछाम न
